# %% [markdown]
# # データの取得

# %%
# ライブラリの読み込み
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from pathlib import Path

# %%
# サンプルデータセットの読み込み
data = load_breast_cancer()

# %%
# pandas Dataframe形式で説明変数Xを取得
df_X = pd.DataFrame(data.data, columns=data.feature_names)

# %%
# pandas Series形式で目的変数yを取得
s_y = pd.Series(data.target)

# %%
# pandas Dataframe形式で目的変数と説明変数を結合したXyを取得
df_Xy = pd.concat([df_X, s_y], axis=1, join='inner')

# %%
# colum最終列にある目的変数に名前がついていないので"target'という名前に変更
df_Xy = df_Xy.rename(columns={0:"target"})

# %% [markdown]
# # データセットの概要を確認

# %%
# データセットの最初の10行くらいをみてみる
df_Xy.head(10)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# ...

# %%
# 説明変数の種類、欠損値の有無、データ型を確認
df_Xy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
# 欠損値の有無に着目したいときはisnull()関数を使う
df_Xy.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
# 説明変数ごとの平均・標準偏差、４分位数の確認
df_Xy.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
# カテゴリー変数の場合は、uniqueな値を確認しておく。（unique関数はSeries形式に対して使う）
df_Xy['target'].unique()
# Out:
# array([0, 1])

# %%
# カテゴリー変数の場合は、カテゴリごとの数を確認してみる
df_Xy['target'].value_counts()
# Out:
# 1    357
# 0    212
# Name: target, dtype: int64

# %%
# 相関行列
corr_mat = df_Xy.corr()
corr_mat
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %% [markdown]
# # データの可視化

# %%
'''
特徴量ごとのヒストグラムを描写する
特徴量が少ない場合は

sns.pairplot(data=df_Xy, hue='target', kind='reg').savefig('pairplot.png', facecolor='white')

といった形ですべてのヒストグラムと散布図の組み合わせを一括で確認することも出来る
'''


for i, col in enumerate(df_Xy.columns):
    # ヒストグラムの描写
    fig = plt.figure(facecolor="white") #背景色を白に設定
    sns.histplot(df_Xy[df_Xy['target'] == 0][col], kde=True, color='salmon')
    sns.histplot(df_Xy[df_Xy['target'] == 1][col], kde=True, color='royalblue')
    labels = ['Target=0(kde)', 'Target=1(kde)', 'Target=0(Count)', 'Target=1(Count)']
    plt.legend(labels)
    folder = Path('output/hist')
    filename = col+'_hist.png'
    file = folder / filename
    plt.savefig(file) # output/histディレクトリ配下にグラフ画像吐き出し
    plt.close() # 画像数が多い場合はplt.close()で閉じてメモリ節約

# %%
# 相関行列からヒートマップを作成
plt.figure(figsize=(25,25), facecolor="white") # 出力する画像サイズと背景色の設定
sns.heatmap(corr_mat,
            vmin=-1.0,
            vmax=1.0,
            center=0,
            annot=True, # True:格子の中に値を表示
            xticklabels=corr_mat.columns.values,
            yticklabels=corr_mat.columns.values
           )
folder = Path('output/heatmap')
filename = 'heatmap.png'
file = folder / filename
plt.savefig(file)
plt.figure()
